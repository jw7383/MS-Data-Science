# %% [markdown]
# ---
#
# ### DSGA1007
#
# ---
#
# ### HW01
# ### Due Date: 2021-09-24, 5PM

# %% [markdown]
# Firstname: Jason
#
# Lastname: Wang
#
# E-mail: jw7383@nyu.edu
#
#
# ---
#
# Enter your solutions below,  and submit this notebook

# %% [markdown]
# ### Problem 01 (25 points):
#
# Two given data sets "ClassA.csv" and "ClassB.csv" represent the number of points obtained by students at quizzes for two different classes A and B.
#
# So, every row in "ClassA.csv" represents points obtained by a student in class A. Similarly for the class B.
#
# Write a function which displays:
#
# - number of students for each A and B
#
# - number of quizzes for each class A and B
#
#
# - the average number of points for every student for each class A and B
#
# - the min number of points for every student for each class A and B
#
# - the max number of points for every student for each class A and B
#
# - the standard deviation of the number of points for every student for each class A and B
#
#
# - the average number of points over for every quiz for each class A and B
#
# - the min number of points over for every quiz for each class A and B
#
# - the max number of points over for every quiz for each class A and B
#
# - the standard deviation for the number of points over for every quiz for each class A and B

# %%
### Solution 01

import numpy as np

def examine_results(fileA, fileB):
    print('Number of students in A: ', np.shape(fileA)[0])
    print('Number of students in B: ',np.shape(fileB)[0])
    print('Number of quizzes in A: ', np.shape(fileA)[1])
    print('Number of quizzes in B: ', np.shape(fileB)[1])
    print('-' * 80)
    print('Average number of points for each student in A: ', np.mean(fileA, axis = 1))
    print('Average number of points for each student in B: ', np.mean(fileB, axis = 1))
    print('Minimum number of points for each student in A: ', np.min(fileA, axis = 1))
    print('Minimum number of points for each student in B: ', np.min(fileB, axis = 1))
    print('Maximum number of points for each student in A: ', np.max(fileA, axis = 1))
    print('Maximum number of points for each student in B: ', np.max(fileB, axis = 1))
    print('Standard deviation of number of points for each student in A: ', np.std(fileA, axis = 1))
    print('Standard deviation of number of points for each student in B: ', np.std(fileB, axis = 1))
    print('-' * 80)
    print('Average number of points for each quiz in A: ', np.mean(fileA, axis = 0))
    print('Average number of points for each quiz in B: ', np.mean(fileB, axis = 0))
    print('Minimum number of points for each quiz in A: ', np.min(fileA, axis = 0))
    print('Minimum number of points for each quiz in B: ', np.min(fileB, axis = 0))
    print('Maximum number of points for each quiz in A: ', np.max(fileA, axis = 0))
    print('Maximum number of points for each quiz in B: ', np.max(fileB, axis = 0))
    print('Standard deviation of number of points for each quiz in A: ', np.std(fileA, axis = 0))
    print('Standard deviation of number of points for each quiz in B: ', np.std(fileB, axis = 0))

### run your solution
A = np.loadtxt(fname = 'ClassA.csv', delimiter = ',')
B = np.loadtxt(fname = 'ClassB.csv', delimiter = ',')
examine_results(A,B)
# Out:
# Number of students in A:  10
# Number of students in B:  10
# Number of quizzes in A:  5
# Number of quizzes in B:  5
# --------------------------------------------------------------------------------
# Average number of points for each student in A:  [79.8 86.4 74.6 88.8 74.6 79.8 79.6 84.8 76.  78.6]
# Average number of points for each student in B:  [80.6 82.2 88.4 76.2 82.6 80.  82.4 78.6 79.8 78.2]
# Minimum number of points for each student in A:  [60. 61. 60. 74. 61. 72. 70. 68. 63. 61.]
# Minimum number of points for each student in B:  [72. 71. 80. 67. 77. 73. 68. 73. 67. 68.]
# Maximum number of points for each student in A:  [93. 98. 91. 98. 87. 96. 90. 94. 92. 98.]
# Maximum number of points for each student in B:  [92. 88. 93. 88. 92. 89. 94. 89. 88. 91.]
# Standard deviation of number of points for each student in A:  [10.94349122 13.09350984 10.32666451  8.42377588  9.09065454  8.63481326
#   6.52993109  8.9977775   9.44457516 12.33855745]
# Standard deviation of number of points for each student in B:  [7.31026675 6.43117408 4.84148737 7.88416134 5.60713831 6.69328021
#  8.63944443 5.74804315 8.32826513 9.49526198]
# --------------------------------------------------------------------------------
# Average number of points for each quiz in A:  [83.  80.8 76.9 78.8 82. ]
# Average number of points for each quiz in B:  [82.5 80.9 83.  80.7 77.4]
# Minimum number of points for each quiz in A:  [63. 69. 60. 68. 61.]
# Minimum number of points for each quiz in B:  [67. 68. 68. 71. 67.]
# Maximum number of points for each quiz in A:  [95. 98. 96. 98. 98.]
# Maximum number of points for each quiz in B:  [94. 93. 91. 92. 92.]
# Standard deviation of number of points for each quiz in A:  [ 9.20869155  9.90757286 14.41145378  8.81816307 10.55461984]
# Standard deviation of number of points for each quiz in B:  [8.12711511 8.76869432 7.25258575 6.26178888 7.60526134]

# %% [markdown]
# ### Problem 02 (50 points)
#
#
# Create two random matrices of dimension 10 by 10:
#
# (5 points)
# a. $U$, where each entry is drawn independently from the uniform distribution on $[0, 1]$
#
# (5 points)
# b. $G$, where each entry is drawn independently from the normal (Gaussian) distribution with mean 0 and standard deviation 1.
#
#
# (30 points)
# - Write a function which for a given input matrix M outputs two vectors:
#
# avg_row, avg_col which are averages over rows and columns in the given matrix M
#
#
# ```
# def matrix_avg(M):
#     return avg_row, avg_col
# ```
#
# - Write a function which for a given input matrix M outputs a matrix where each entry of M is squared;
#
#
#
# ```
# def matrix_sq(M):
#     return M_sq
# ```
#
#
# - Write a function which for a given input matrix M outputs a matrix where each entry of M is raised at the power k:
#
#
# ```
# def matrix_power(M, k):
#     return M_power
# ```
#
#
# - Report outputs of when `matrix_avg`, `matrix_sq` and `matrix_power` for `k=3` applied on both $U$ and $G$;
# there are 6 outputs.
#
#
#
# (10 points)
#
# Write a function which displays the output of the convolution:
#
# `matrix_avg(matrix_power(M, t))` when $t$ takes values from $t=1, 2, \dots, 10$.
#
#
# ```
# def matrix_powers_examine(M):
#     return
# ```
#
# - Report output of the above on both $U$ and $G$.

# %%
### Solution 02 
U = np.random.rand(10,10)
G = np.random.randn(10,10)

def matrix_avg(M):
    avg_row = np.mean(M, axis = 1)
    avg_col = np.mean(M, axis = 0)
    return avg_row, avg_col

def matrix_sq(M):
    M_sq = np.square(M)
    return M_sq

def matrix_power(M,k):
    M_power = np.power(M,k)
    return M_power

print(matrix_avg(U))
print('-' * 80)
print(matrix_avg(G))
print('-' * 80)
print(matrix_sq(U))
print('-' * 80)
print(matrix_sq(G))
print('-' * 80)
print(matrix_power(U,3))
print('-' * 80)
print(matrix_power(G,3))
print('-' * 80)

def matrix_powers_examine(M):
#        0.45622555, 0.62755512, 0.50844102, 0.40840947, 0.60274005]), array([0.58570561, 0.47379727, 0.28960986, 0.43590382, 0.68966553,
#        0.5330119 , 0.53285501, 0.47982342, 0.53211569, 0.48290743]))
# t =  2
# (array([0.32553591, 0.41290599, 0.21780512, 0.34959374, 0.35309875,
#        0.30103238, 0.49715128, 0.30900429, 0.19878182, 0.44987251]), array([0.4208027 , 0.28254394, 0.13486887, 0.25894389, 0.5168134 ,
#        0.38481934, 0.37963926, 0.33722439, 0.36971232, 0.32941368]))
# t =  3
# (array([0.23746529, 0.32114577, 0.1533107 , 0.27255044, 0.29879571,
#        0.23267075, 0.42333339, 0.21021135, 0.10608794, 0.36012025]), array([0.33135766, 0.1829255 , 0.09000102, 0.17514745, 0.41155973,
#        0.30687886, 0.30743634, 0.27354777, 0.27840615, 0.25843112]))
# t =  4
# (array([0.18269139, 0.26574647, 0.11868665, 0.22690894, 0.26515739,
#        0.19542278, 0.37158648, 0.15263535, 0.06039887, 0.29904014]), array([0.27406299, 0.12531781, 0.07146761, 0.12798293, 0.34247865,
#        0.25881839, 0.26342916, 0.23598283, 0.22023583, 0.21849825]))
# t =  5
# (array([0.14520511, 0.22812062, 0.09665777, 0.19656297, 0.24198077,
#        0.17221562, 0.33135729, 0.11512135, 0.03623571, 0.25385969]), array([0.23389309, 0.08977858, 0.06081643, 0.09858109, 0.29429088,
#        0.2260951 , 0.23180537, 0.20930124, 0.18050109, 0.19225404]))
# t =  6
# (array([0.11793716, 0.20029508, 0.08094327, 0.17470002, 0.22473359,
#        0.1561872 , 0.29838562, 0.08889496, 0.02270878, 0.21872484]), array([0.2041324 , 0.06663388, 0.05321385, 0.07878736, 0.25899737,
#        0.20197299, 0.20674887, 0.188377  , 0.15192325, 0.17272355]))
# t =  7
# (array([0.09727671, 0.17844812, 0.06887666, 0.15795406, 0.21107112,
#        0.14413393, 0.27055128, 0.0697311 , 0.01474945, 0.19051556]), array([0.18121512, 0.05083378, 0.04713394, 0.06463592, 0.2321205 ,
#        0.18301441, 0.18578835, 0.17111661, 0.13053794, 0.15691143]))
# t =  8
# (array([0.08117012, 0.16056531, 0.0591826 , 0.14450996, 0.19970805,
#        0.134424  , 0.24661224, 0.055318  , 0.00985644, 0.16735509]), array([0.16302623, 0.03960597, 0.04199238, 0.05403952, 0.21100057,
#        0.16735766, 0.16773304, 0.15646942, 0.11402813, 0.1434489 ]))
# t =  9
# (array([0.06834852, 0.14549434, 0.05117918, 0.13332239, 0.18991087,
#        0.12617975, 0.22575299, 0.04425963, 0.00673345, 0.14801298]), array([0.1482203 , 0.03135795, 0.03752146, 0.04582096, 0.1939732 ,
#        0.15394765, 0.15192892, 0.14381003, 0.10095542, 0.13165822]))
# t =  10
# (array([0.05797697, 0.13252716, 0.04446013, 0.12375354, 0.18124429,
#        0.11891075, 0.20739629, 0.03565046, 0.00467735, 0.13163508]), array([0.13590129, 0.0251341 , 0.03357762, 0.03927247, 0.17994854,
#        0.14216223, 0.13796623, 0.13272093, 0.09038116, 0.12116744]))
# --------------------------------------------------------------------------------
# t =  1
# (array([-0.16747941,  0.11115299,  0.52825619, -0.28004328,  0.74073111,
#        -0.21935465,  0.50997119,  0.49041351, -0.11620304,  0.96129831]), array([ 0.25283414,  0.03167225,  0.22347966,  0.45869551,  0.33713149,
#        -0.32271828,  0.77951199,  0.38269906,  0.16639497,  0.24904214]))
# t =  2
# (array([0.33096862, 1.23274164, 1.24370284, 0.97025122, 1.57115997,
#        0.77141398, 0.75747928, 1.14907962, 0.81753584, 1.50355241]), array([1.53301763, 0.68982431, 0.93344079, 0.82998346, 1.12522209,
#        0.57508338, 1.2376666 , 1.05433144, 0.85310468, 1.51621104]))
# t =  3
# (array([-0.27007834, -0.11264592,  1.47153394, -0.27917926,  2.53332024,
#        -0.5597859 ,  1.38762993,  1.08147785,  0.10914259,  2.60805349]), array([ 0.72486245,  0.45081304,  0.67068542,  0.48665272,  0.91100646,
#        -0.51338055,  2.28673188,  0.82055152,  0.21257875,  1.9189669 ]))
# t =  4
# (array([0.39383042, 3.75257808, 2.87932655, 1.60556065, 5.32354182,
#        1.1260188 , 3.06542489, 2.41464906, 1.36204363, 5.00710892]), array([6.06787826, 1.06399059, 1.89054592, 1.233059  , 2.32952376,
#        0.82940493, 4.59174083, 2.29692385, 1.53037402, 5.09664164]))
# t =  5
# (array([-0.49310885, -2.22374689,  4.36669028, -0.36810354, 10.92698699,
#        -1.12212868,  6.99599726,  2.79840994,  0.69375716, 10.26146353]), array([ 3.87062715,  1.34598366,  1.79089845,  0.87336983,  2.72507695,
#        -0.9830425 ,  9.60235903,  2.40684199,  0.68700429,  9.51709836]))
# t =  6
# (array([ 0.68230453, 14.1473645 ,  7.92367994,  3.23950497, 24.00391264,
#         1.88366042, 16.23201282,  5.95907384,  2.85736893, 22.06048469]), array([29.92978593,  2.38529001,  4.3326786 ,  2.31905867,  5.70822762,
#         1.4670764 , 20.63116849,  6.25311311,  3.38019662, 22.58277185]))
# t =  7
# (array([ -0.9228562 , -14.94407016,  13.30216741,  -0.41057992,
#         53.54490607,  -2.14336926,  37.80730685,   7.89077836,
#          2.42318543,  49.01080047]), array([24.84835567,  3.67913654,  4.85749252,  1.95210873,  7.93788132,
#        -1.91646158, 45.22453429,  8.12179808,  2.37007043, 48.48335304]))
# t =  8
# (array([  1.26832507,  57.8563925 ,  23.83202359,   6.97593785,
#        122.27369696,   3.29292206,  88.19504719,  15.79816331,
#          6.68579879, 111.31918695]), array([156.88598933,   6.17494905,  10.64022192,   4.77962674,
#         15.0239048 ,   2.74328215, 100.68233169,  19.19306836,
#          8.18039382, 113.1937264 ]))
# t =  9
# (array([-1.73715986e+00, -8.20460268e+01,  4.19272375e+01, -9.43968667e-02,
#         2.82717322e+02, -4.02253484e+00,  2.05827799e+02,  2.28741242e+01,
#         7.43587563e+00,  2.56571830e+02]), array([161.45666191,  10.06274711,  13.51651565,   4.65787671,
#         22.86140915,  -3.71603334, 226.84968592,  28.89080518,
#          7.62943711, 257.2449642 ]))
# t =  10
# (array([  2.38560577, 247.89274181,  75.66810132,  15.37999217,
#        660.62037968,   5.88818861, 480.43262331,  43.51201574,
#         16.60658251, 597.10391874]), array([842.24170767,  16.74872662,  27.51839735,  10.3114822 ,
#         41.10322664,   5.22177922, 515.82901915,  63.06134748,
#         20.82898107, 602.62548229]))

# %% [markdown]
# ### Problem 03 (25 points)
#
# For the given text below, write a function which displays the text and returns a dictionary call it `char_counts`; where the dictionary maps all distinct characters of the text into the number of their occurrences in the given text.
#
# For example, `char_counts['A'] = 1` since `A` only appeared once in the word "Avenue".
#
#
# Finally, print the obtained dictionary `char_counts` and its length.

# %%
text = "The Center for Data Science (CDS) is the focal point for New York University’s university-wide efforts in Data Science. The Center was established in 2013 to advance NYU’s goal of creating a world-leading Data Science training and research facility, and arming researchers and professionals with the tools to harness the power of Big Data. Today, CDS counts 16 jointly appointed interdisciplinary faculty housed on two floors of our magnificent 60 5th Avenue building, one of New York City’s historic properties. It is home to a top-ranked MS in Data Science program, one of the first PhD programs in Data Science, and a new undergraduate program in Data Science, as well as a lively Fellow and Postdoctoral program. It has over 60 associate and affiliate faculty from 25 departments in 9 schools and units. With cross-disciplinary research and innovative educational programs, CDS is shaping the new field of Data Science."

# %%
### Solution 03 

def text_process(text):
    print(text)
    char_counts = {}
    for i in range(0,len(text)):
        if text[i] in char_counts:
            char_counts[text[i]] += 1
        else:
            char_counts[text[i]] = 1
    return char_counts
    
dict = text_process(text)
print('char_counts: ', dict)
print('Length of char_counts: ', len(dict))
# Out:
# The Center for Data Science (CDS) is the focal point for New York University’s university-wide efforts in Data Science. The Center was established in 2013 to advance NYU’s goal of creating a world-leading Data Science training and research facility, and arming researchers and professionals with the tools to harness the power of Big Data. Today, CDS counts 16 jointly appointed interdisciplinary faculty housed on two floors of our magnificent 60 5th Avenue building, one of New York City’s historic properties. It is home to a top-ranked MS in Data Science program, one of the first PhD programs in Data Science, and a new undergraduate program in Data Science, as well as a lively Fellow and Postdoctoral program. It has over 60 associate and affiliate faculty from 25 departments in 9 schools and units. With cross-disciplinary research and innovative educational programs, CDS is shaping the new field of Data Science.
# char_counts:  {'T': 3, 'h': 22, 'e': 73, ' ': 148, 'C': 6, 'n': 57, 't': 55, 'r': 50, 'f': 22, 'o': 56, 'D': 12, 'a': 72, 'S': 11, 'c': 33, 'i': 62, '(': 1, ')': 1, 's': 45, 'l': 26, 'p': 17, 'N': 3, 'w': 12, 'Y': 3, 'k': 3, 'U': 2, 'v': 8, 'y': 11, '’': 3, 'u': 12, '-': 4, 'd': 26, '.': 6, 'b': 2, '2': 2, '0': 3, '1': 2, '3': 1, 'g': 15, ',': 7, 'm': 10, 'B': 1, '6': 3, 'j': 1, '5': 2, 'A': 1, 'I': 2, 'M': 1, 'P': 2, 'F': 1, '9': 1, 'W': 1}
# Length of char_counts:  51
